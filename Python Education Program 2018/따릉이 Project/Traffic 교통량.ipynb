# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['font.family'].insert(0, 'Malgun Gothic')  #Malgun Gothic(Windows) -> AppleGothic(mac OS)
# %matplotlib inline

# %% [markdown]
# # data 불러오기

# %%
#교통량 데이터 (2016년 3분기~2018년 1분기)

data_2016_7= pd.read_excel("교통량데이터/2016년 7월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2016_8= pd.read_excel("교통량데이터/2016년 8월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2016_9= pd.read_excel("교통량데이터/2016년 9월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2016_10= pd.read_excel("교통량데이터/2016년 10월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2016_11= pd.read_excel("교통량데이터/2016년 11월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2016_12= pd.read_excel("교통량데이터/2016년 12월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2017_01= pd.read_excel("교통량데이터/2017년 1월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2017_02= pd.read_excel("교통량데이터/2017년 2월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2017_03= pd.read_excel("교통량데이터/2017년 3월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2017_04= pd.read_excel("교통량데이터/2017년 4월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2017_05= pd.read_excel("교통량데이터/2017년 5월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2017_06= pd.read_excel("교통량데이터/2017년 6월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2017_07= pd.read_excel("교통량데이터/2017년 7월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2017_08= pd.read_excel("교통량데이터/2017년 8월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2017_09= pd.read_excel("교통량데이터/2017년 9월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2017_10= pd.read_excel("교통량데이터/2017년 10월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2017_11= pd.read_excel("교통량데이터/2017년 11월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2017_12= pd.read_excel("교통량데이터/2017년 12월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2018_01= pd.read_excel("교통량데이터/2018년 1월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2018_02= pd.read_excel("교통량데이터/2018년 2월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")
data_2018_03= pd.read_excel("교통량데이터/2018년 3월 서울시 교통량 조사자료.xlsx", encoding = "euc_kr", sep=",")

# %%
#맛보기용

data_2018_03.head()
# Out:
#          일자 요일        지점명  지점번호  방향            구분     0시     1시     2시     3시  \
# 0  20180301  목  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  648.0  537.0  402.0  366.0
# 1  20180302  금  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  476.0  346.0  245.0  212.0
# 2  20180303  토  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  758.0  593.0  443.0  339.0
# 3  20180304  일  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  553.0  423.0  336.0  261.0
# 4  20180305  월  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  372.0  234.0  180.0  186.0
#
#     ...       14시     15시     16시     17시     18시     19시     20시     21시  \
# 0   ...    1799.0  1173.0  1076.0  1039.0  1284.0  1416.0  1174.0  1123.0
# 1   ...    1970.0  2120.0  2143.0  2195.0  2287.0  1720.0  1356.0  1471.0
# 2   ...    2032.0  1965.0  2010.0  1967.0  1782.0  1534.0  1132.0  1185.0
# 3   ...    1542.0  1644.0  1599.0  1556.0  1423.0  1132.0   992.0   966.0
# 4   ...    1773.0  2020.0  2022.0  2256.0  2235.0  1732.0  1458.0  1427.0
#
#       22시     23시
# 0   906.0   744.0
# ...

# %% [markdown]
# # data 분기 concat

# %%
#데이터 분기 합치기 
##2016년 3분기 
data_201603=pd.concat([data_2016_7,data_2016_8,data_2016_9],axis=0,sort=False, ignore_index = True)
##2016년 4분기 
data_201604=pd.concat((data_2016_10,data_2016_11,data_2016_12),axis=0,sort=False, ignore_index = True)
##2017년 1분기 
data_201701=pd.concat((data_2017_01,data_2017_02,data_2017_03),axis=0,sort=False, ignore_index = True)
##2017년 2분기 
data_201702=pd.concat((data_2017_04,data_2017_05,data_2017_06),axis=0,sort=False, ignore_index = True)
##2017년 3분기 
data_201703=pd.concat((data_2017_07,data_2017_08,data_2017_09),axis=0,sort=False, ignore_index = True)
##2017년 4분기 
data_201704=pd.concat((data_2017_10,data_2017_11,data_2017_12),axis=0,sort=False, ignore_index = True)
##2018년 1분기
data_201801=pd.concat((data_2018_01,data_2018_02,data_2018_03),axis=0,sort=False, ignore_index = True)

# %%
data_201603.head()
# Out:
#          일자 요일        지점명  지점번호  구분            방향     0시     1시     2시     3시  \
# 0  20160701  금  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  848.0  662.0  440.0  346.0
# 1  20160702  토  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  758.0  539.0  444.0  335.0
# 2  20160703  일  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  713.0  504.0  413.0  281.0
# 3  20160704  월  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  477.0  345.0  247.0  189.0
# 4  20160705  화  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  613.0  488.0  312.0  252.0
#
#     ...       14시     15시     16시     17시     18시     19시     20시     21시  \
# 0   ...    1993.0  1777.0  2086.0  2211.0  2270.0  1950.0  1740.0  1379.0
# 1   ...    2189.0  1983.0  2110.0  2138.0  1849.0  1590.0  1226.0  1342.0
# 2   ...    1694.0  1707.0  1539.0  1650.0  1375.0  1237.0  1144.0  1149.0
# 3   ...    1957.0  2020.0  2078.0  2133.0  2086.0  1749.0  1358.0  1334.0
# 4   ...    2056.0  2053.0  2201.0  2309.0  2243.0  1717.0  1396.0  1434.0
#
#       22시     23시
# 0  1218.0   985.0
# ...

# %%
data_201801.head()
# Out:
#          일자 요일        지점명  지점번호  구분            방향     0시     1시     2시     3시  \
# 0  20180101  월  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  657.0  617.0  405.0  279.0
# 1  20180102  화  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  382.0  256.0  166.0  171.0
# 2  20180103  수  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  641.0  492.0  310.0  238.0
# 3  20180104  목  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  661.0  483.0  357.0  279.0
# 4  20180105  금  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  764.0  524.0  361.0  282.0
#
#     ...       14시     15시     16시     17시     18시     19시     20시     21시  \
# 0   ...    1401.0  1592.0  1515.0  1447.0  1192.0  1037.0   918.0   881.0
# 1   ...    1690.0  1835.0  1875.0  2021.0  2015.0  1612.0  1236.0  1308.0
# 2   ...    1841.0  2007.0  1940.0  2096.0  2209.0  1653.0  1387.0  1295.0
# 3   ...    1890.0  2030.0  2058.0  2123.0  2113.0  1619.0  1327.0  1379.0
# 4   ...    1860.0  2134.0  2163.0  2282.0  2307.0  1723.0  1577.0  1460.0
#
#       22시     23시
# 0   819.0   533.0
# ...

# %% [markdown]
# # 교통량이 가장 많은 시간대는? 유입/유출

# %%
#분기별
##2016 3분기 

data_201603_유입=data_201603[data_201603['구분']=='유입']
data_201603_유출=data_201603[data_201603['구분']=='유출']

# %%
data_201603_유입.head()
# Out:
#          일자 요일        지점명  지점번호  구분            방향     0시     1시     2시     3시  \
# 0  20160701  금  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  848.0  662.0  440.0  346.0
# 1  20160702  토  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  758.0  539.0  444.0  335.0
# 2  20160703  일  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  713.0  504.0  413.0  281.0
# 3  20160704  월  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  477.0  345.0  247.0  189.0
# 4  20160705  화  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  613.0  488.0  312.0  252.0
#
#     ...       14시     15시     16시     17시     18시     19시     20시     21시  \
# 0   ...    1993.0  1777.0  2086.0  2211.0  2270.0  1950.0  1740.0  1379.0
# 1   ...    2189.0  1983.0  2110.0  2138.0  1849.0  1590.0  1226.0  1342.0
# 2   ...    1694.0  1707.0  1539.0  1650.0  1375.0  1237.0  1144.0  1149.0
# 3   ...    1957.0  2020.0  2078.0  2133.0  2086.0  1749.0  1358.0  1334.0
# 4   ...    2056.0  2053.0  2201.0  2309.0  2243.0  1717.0  1396.0  1434.0
#
#       22시     23시
# 0  1218.0   985.0
# ...

# %%
data_201603_총유입=data_201603_유입.drop(['구분','방향','요일','지점명','지점번호','일자'], axis=1)
data_201603_총유입=data_201603_총유입.sum()
data_201603_총유출=data_201603_유출.drop(['구분','방향','요일','지점명','지점번호','일자'], axis=1)
data_201603_총유출=data_201603_총유출.sum()

# %%
data_201603_총유입.head()
# Out:
# 0시    10165261.0
# 1시     7662410.0
# 2시     5894239.0
# 3시     4955160.0
# 4시     5604532.0
# dtype: float64

# %%
data_201603_총유출.head()
# Out:
# 0시    10489352.0
# 1시     7852143.0
# 2시     6052653.0
# 3시     5118344.0
# 4시     5695786.0
# dtype: float64

# %%
#시간대별 유입 교통량 

data_201603_총유입.head(30).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel('시간대')
plt.ylabel('유입교통량')
# Out:
# Text(0,0.5,'유입교통량')

# %%
#시간대별 유출 교통량 

data_201603_총유출.head(30).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel('시간대')
plt.ylabel('유출교통량')
# Out:
# Text(0,0.5,'유출교통량')

# %%
data_201603_총유입.sort_values()

#유입교통량은 새벽 3시가 가장 적고 그 다음 4시 2시 1시 임을 알 수 있다. 
#가장 많은 시간대는 17시이다
# Out:
# 3시      4955160.0
# 4시      5604532.0
# 2시      5894239.0
# 1시      7662410.0
# 5시      9760162.0
# 0시     10165261.0
# 23시    13321784.0
# 6시     16471560.0
# 22시    16981430.0
# 21시    18669222.0
# 20시    18799292.0
# 19시    20075147.0
# 7시     20708626.0
# 12시    20912467.0
# 11시    21517659.0
# 13시    21531801.0
# 10시    21607780.0
# 14시    21689517.0
# 15시    21755154.0
# 18시    21780981.0
# 9시     21816561.0
# 8시     21897918.0
# 16시    22012049.0
# 17시    22292625.0
# dtype: float64

# %%
data_201603_총유출.sort_values()

#유출교통량은 유입과 마찬가지로 새벽 3시가 가장 적고 그 다음 4시 2시 1시 임을 알 수 있다. 
#가장 많은 시간대는 17시이다
# Out:
# 3시      5118344.0
# 4시      5695786.0
# 2시      6052653.0
# 1시      7852143.0
# 5시      9584125.0
# 0시     10489352.0
# 23시    13644041.0
# 6시     15000656.0
# 22시    16990031.0
# 21시    18324790.0
# 20시    18331045.0
# 7시     18435093.0
# 12시    19568277.0
# 19시    19632657.0
# 8시     19704760.0
# 9시     19710713.0
# 10시    19789069.0
# 11시    19888262.0
# 13시    20065407.0
# 14시    20240495.0
# 15시    20547242.0
# 16시    21010280.0
# 18시    21056703.0
# 17시    21501270.0
# dtype: float64

# %%
##2016 4분기 

data_201604_유입=data_201604[data_201604['구분']=='유입']
data_201604_유출=data_201604[data_201604['구분']=='유출']

# %%
data_201604_총유입=data_201604_유입.drop(['구분','방향','요일','지점명','지점번호','일자'], axis=1)
data_201604_총유입=data_201604_총유입.sum()
data_201604_총유출=data_201604_유출.drop(['구분','방향','요일','지점명','지점번호','일자'], axis=1)
data_201604_총유출=data_201604_총유출.sum()

# %%
#시간대별 유입 교통량 

data_201604_총유입.head(30).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel('시간대')
plt.ylabel('유입교통량')
# Out:
# Text(0,0.5,'유입교통량')

# %%
#시간대별 유출 교통량 

data_201604_총유출.head(30).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel('시간대')
plt.ylabel('유출교통량')
# Out:
# Text(0,0.5,'유출교통량')

# %%
data_201604_총유입.sort_values()

#유입교통량은 새벽 3시가 가장 적고 그 다음 4시 2시 1시 임을 알 수 있다. 
#가장 많은 시간대는 8시,9시이다
# Out:
# 3시      5049162.0
# 4시      5513308.0
# 2시      6016707.0
# 1시      7700201.0
# 5시      9440209.0
# 0시     10022251.0
# 23시    12867218.0
# 6시     15880671.0
# 22시    16201079.0
# 21시    17622069.0
# 20시    17969952.0
# 19시    19496669.0
# 7시     20568861.0
# 12시    20658138.0
# 18시    21011034.0
# 11시    21340089.0
# 13시    21396954.0
# 17시    21413570.0
# 14시    21557485.0
# 15시    21558079.0
# 10시    21645903.0
# 16시    21676796.0
# 9시     21880756.0
# 8시     22004061.0
# dtype: float64

# %%
data_201604_총유출.sort_values()

#유출교통량은 유입과 마찬가지로 새벽 3시가 가장 적고 그 다음 4시 2시 1시 임을 알 수 있다. 
#가장 많은 시간대는 16시,17시이다
# Out:
# 3시      5151112.0
# 4시      5435833.0
# 2시      6144814.0
# 1시      7854228.0
# 5시      8978071.0
# 0시     10377026.0
# 23시    13293603.0
# 6시     14258026.0
# 22시    16568580.0
# 21시    17578191.0
# 20시    17756484.0
# 7시     18209716.0
# 19시    19145637.0
# 12시    19209525.0
# 8시     19641570.0
# 11시    19643882.0
# 9시     19735367.0
# 10시    19827875.0
# 13시    19831738.0
# 14시    20191415.0
# 18시    20333619.0
# 15시    20493448.0
# 17시    20757668.0
# 16시    20802089.0
# dtype: float64

# %%
##2017 1분기 

data_201701_유입=data_201701[data_201701['구분']=='유입']
data_201701_유출=data_201701[data_201701['구분']=='유출']

# %%
data_201701_총유입=data_201701_유입.drop(['구분','방향','요일','지점명','지점번호','일자'], axis=1)
data_201701_총유입=data_201701_총유입.sum()
data_201701_총유출=data_201701_유출.drop(['구분','방향','요일','지점명','지점번호','일자'], axis=1)
data_201701_총유출=data_201701_총유출.sum()

# %%
#시간대별 유입 교통량 

data_201701_총유입.head(30).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel('시간대')
plt.ylabel('유입교통량')
# Out:
# Text(0,0.5,'유입교통량')

# %%
#시간대별 유출 교통량 

data_201701_총유출.head(30).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel('시간대')
plt.ylabel('유출교통량')
# Out:
# Text(0,0.5,'유출교통량')

# %%
data_201701_총유입.sort_values()

#유입교통량은 새벽 3시가 가장 적고 그 다음 4시 2시 1시 임을 알 수 있다. 
#가장 많은 시간대는 8시,9시이다
# Out:
# 3시      4148488.0
# 4시      4493836.0
# 2시      4935422.0
# 1시      6366791.0
# 5시      7346333.0
# 0시      8906829.0
# 23시    10640919.0
# 6시     13094758.0
# 22시    13675062.0
# 21시    15068756.0
# 20시    15386856.0
# 19시    16915475.0
# 7시     17778005.0
# 12시    18371222.0
# 18시    18610501.0
# 11시    19011089.0
# 13시    19112209.0
# 14시    19217364.0
# 15시    19333705.0
# 10시    19351472.0
# 17시    19366701.0
# 16시    19478194.0
# 8시     19517512.0
# 9시     19617028.0
# dtype: float64

# %%
data_201701_총유출.sort_values()

#유출교통량은 유입과 마찬가지로 새벽 3시가 가장 적고 그 다음 4시 2시 1시 임을 알 수 있다. 
#가장 많은 시간대는 17시,16시이다
# Out:
# 3시      4352162.0
# 4시      4529333.0
# 2시      5170462.0
# 1시      6675632.0
# 5시      7210411.0
# 0시      8878388.0
# 23시    11181096.0
# 6시     12059847.0
# 22시    14363326.0
# 7시     15585645.0
# 21시    15617821.0
# 20시    15827823.0
# 19시    17128833.0
# 12시    17143443.0
# 8시     17160202.0
# 9시     17365835.0
# 10시    17520295.0
# 11시    17572190.0
# 13시    17701535.0
# 14시    17954681.0
# 15시    18320354.0
# 18시    18368471.0
# 16시    18692204.0
# 17시    18842431.0
# dtype: float64

# %%
##2017 2분기 

data_201702_유입=data_201702[data_201702['구분']=='유입']
data_201702_유출=data_201702[data_201702['구분']=='유출']

# %%
data_201702_총유입=data_201702_유입.drop(['구분','방향','요일','지점명','지점번호','일자'], axis=1)
data_201702_총유입=data_201702_총유입.sum()
data_201702_총유출=data_201702_유출.drop(['구분','방향','요일','지점명','지점번호','일자'], axis=1)
data_201702_총유출=data_201702_총유출.sum()

# %%
#시간대별 유입 교통량 

data_201702_총유입.head(30).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel('시간대')
plt.ylabel('유입교통량')
# Out:
# Text(0,0.5,'유입교통량')

# %%
#시간대별 유출 교통량 

data_201702_총유출.head(30).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel('시간대')
plt.ylabel('유출교통량')
# Out:
# Text(0,0.5,'유출교통량')

# %%
data_201702_총유입.sort_values()

#유입교통량은 새벽 3시가 가장 적고 그 다음 4시 2시 1시 임을 알 수 있다. 
#가장 많은 시간대는 17시,8시이다
# Out:
# 3시      5237580.0
# 4시      5911397.0
# 2시      6178278.0
# 1시      7980324.0
# 0시     10176821.0
# 5시     10346896.0
# 23시    13568134.0
# 22시    17418241.0
# 6시     17636605.0
# 21시    19135989.0
# 20시    19401851.0
# 19시    21249175.0
# 12시    21387049.0
# 13시    22234836.0
# 14시    22335721.0
# 7시     22389625.0
# 11시    22397735.0
# 15시    22668280.0
# 10시    22935686.0
# 16시    23044789.0
# 18시    23314572.0
# 9시     23478972.0
# 8시     23524340.0
# 17시    23640495.0
# dtype: float64

# %%
data_201702_총유출.sort_values()

#유출교통량은 유입과 마찬가지로 새벽 3시가 가장 적고 그 다음 4시 2시 1시 임을 알 수 있다. 
#가장 많은 시간대는 17시,18시이다
# Out:
# 3시      5517489.0
# 4시      6053935.0
# 2시      6499193.0
# 1시      8351036.0
# 5시     10636823.0
# 0시     10878097.0
# 23시    14380325.0
# 22시    18130522.0
# 21시    19481429.0
# 20시    19702833.0
# 7시     20428761.0
# 12시    20951857.0
# 13시    21543327.0
# 8시     21560123.0
# 9시     21561877.0
# 19시    21567499.0
# 11시    21701358.0
# 14시    21716570.0
# 10시    21727300.0
# 15시    22228024.0
# 16시    22705242.0
# 18시    23423854.0
# 17시    23485140.0
# dtype: float64

# %%
##2017 3분기 

data_201703_유입=data_201703[data_201703['구분']=='유입']
data_201703_유출=data_201703[data_201703['구분']=='유출']

# %%
data_201703_총유입=data_201703_유입.drop(['구분','방향','요일','지점명','지점번호','일자'], axis=1)
data_201703_총유입=data_201703_총유입.sum()
data_201703_총유출=data_201703_유출.drop(['구분','방향','요일','지점명','지점번호','일자'], axis=1)
data_201703_총유출=data_201703_총유출.sum()

# %%
#시간대별 유입 교통량 

data_201703_총유입.head(30).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel('시간대')
plt.ylabel('유입교통량')
# Out:
# Text(0,0.5,'유입교통량')

# %%
#시간대별 유출 교통량 

data_201703_총유출.head(30).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel('시간대')
plt.ylabel('유출교통량')
# Out:
# Text(0,0.5,'유출교통량')

# %%
data_201703_총유입.sort_values()

#유입교통량은 새벽 3시가 가장 적고 그 다음 4시 2시 1시 임을 알 수 있다. 
#가장 많은 시간대는 17시,8시이다
# Out:
# 3시      5807177.0
# 4시      6554731.0
# 2시      6711316.0
# 1시      8573459.0
# 0시     10937610.0
# 5시     11089854.0
# 23시    14679686.0
# 22시    18386552.0
# 6시     18690733.0
# 21시    20211353.0
# 20시    20571693.0
# 19시    22187116.0
# 12시    23065916.0
# 7시     23497441.0
# 14시    23715424.0
# 13시    23775823.0
# 11시    23779987.0
# 15시    24025398.0
# 18시    24031211.0
# 10시    24178317.0
# 16시    24329807.0
# 9시     24538625.0
# 8시     24639559.0
# 17시    24677373.0
# dtype: float64

# %%
data_201703_총유출.sort_values()

#유출교통량은 유입과 마찬가지로 새벽 3시가 가장 적고 그 다음 4시 2시 1시 임을 알 수 있다. 
#가장 많은 시간대는 17시,18시이다
# Out:
# 3시      5867726.0
# 4시      6466034.0
# 2시      6831569.0
# 1시      8676428.0
# 5시     10818436.0
# 0시     11394772.0
# 23시    15130390.0
# 6시     16864773.0
# 22시    18663585.0
# 21시    20203719.0
# 20시    20587802.0
# 7시     20774270.0
# 12시    21958670.0
# 9시     21997773.0
# 8시     22046272.0
# 10시    22235245.0
# 19시    22267751.0
# 11시    22429538.0
# 13시    22453944.0
# 14시    22495677.0
# 15시    23059898.0
# 16시    23583748.0
# 18시    23908211.0
# 17시    24226237.0
# dtype: float64

# %%
##2017 4분기 

data_201704_유입=data_201704[data_201704['구분']=='유입']
data_201704_유출=data_201704[data_201704['구분']=='유출']

# %%
data_201704_총유입=data_201704_유입.drop(['구분','방향','요일','지점명','지점번호','일자'], axis=1)
data_201704_총유입=data_201704_총유입.sum()
data_201704_총유출=data_201704_유출.drop(['구분','방향','요일','지점명','지점번호','일자'], axis=1)
data_201704_총유출=data_201704_총유출.sum()

# %%
#시간대별 유입 교통량 

data_201704_총유입.head(30).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel('시간대')
plt.ylabel('유입교통량')
# Out:
# Text(0,0.5,'유입교통량')

# %%
#시간대별 유출 교통량 

data_201704_총유출.head(30).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel('시간대')
plt.ylabel('유출교통량')
# Out:
# Text(0,0.5,'유출교통량')

# %%
data_201704_총유입.sort_values()

#유입교통량은 새벽 3시가 가장 적고 그 다음 4시 2시 1시 임을 알 수 있다. 
#가장 많은 시간대는 16시,15시이다
# Out:
# 3시      5614870.0
# 4시      6213988.0
# 2시      6540477.0
# 1시      8172541.0
# 5시     10214211.0
# 0시     10255752.0
# 23시    13479594.0
# 6시     16790143.0
# 22시    17026526.0
# 21시    19140873.0
# 20시    19609076.0
# 19시    21267757.0
# 7시     21579632.0
# 12시    22709433.0
# 18시    22912211.0
# 8시     23234356.0
# 11시    23326377.0
# 14시    23444892.0
# 9시     23545616.0
# 13시    23547762.0
# 10시    23564184.0
# 17시    23583889.0
# 15시    23736816.0
# 16시    23841391.0
# dtype: float64

# %%
data_201704_총유출.sort_values()

#유출교통량은 유입과 마찬가지로 새벽 3시가 가장 적고 그 다음 4시 2시 1시 임을 알 수 있다. 
#가장 많은 시간대는 16시,17시이다
# Out:
# 3시      5732224.0
# 4시      6108893.0
# 2시      6692303.0
# 1시      8392326.0
# 5시      9821947.0
# 0시     10787001.0
# 23시    14109069.0
# 6시     15341019.0
# 22시    17684621.0
# 7시     19440497.0
# 21시    19459251.0
# 20시    19888043.0
# 8시     21291378.0
# 19시    21446470.0
# 9시     21452069.0
# 12시    21492323.0
# 10시    21853265.0
# 11시    21988686.0
# 13시    22224152.0
# 14시    22339842.0
# 18시    22788946.0
# 15시    23011560.0
# 17시    23293097.0
# 16시    23357667.0
# dtype: float64

# %%
##2018 1분기

data_201801_유입=data_201801[data_201801['구분']=='유입']
data_201801_유출=data_201801[data_201801['구분']=='유출']

# %%
data_201801_총유입=data_201801_유입.drop(['구분','방향','요일','지점명','지점번호','일자'], axis=1)
data_201801_총유입=data_201801_총유입.sum()
data_201801_총유출=data_201801_유출.drop(['구분','방향','요일','지점명','지점번호','일자'], axis=1)
data_201801_총유출=data_201801_총유출.sum()

# %%
#시간대별 유입 교통량 

data_201801_총유입.head(30).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel('시간대')
plt.ylabel('유입교통량')
# Out:
# Text(0,0.5,'유입교통량')

# %%
#시간대별 유출 교통량 

data_201801_총유출.head(30).plot(kind='bar')
plt.xticks(rotation='vertical')
plt.xlabel('시간대')
plt.ylabel('유출교통량')
# Out:
# Text(0,0.5,'유출교통량')

# %%
data_201801_총유입.sort_values()

#유입교통량은 새벽 3시가 가장 적고 그 다음 4시 2시 1시 임을 알 수 있다. 
#가장 많은 시간대는 16시,15시이다
# Out:
# 3시      3310813.0
# 4시      3672497.0
# 2시      3904886.0
# 1시      4998977.0
# 5시      5909126.0
# 0시      6372558.0
# 23시     8415689.0
# 6시     10178080.0
# 22시    10556326.0
# 21시    11632398.0
# 20시    11881127.0
# 19시    13083859.0
# 7시     13644939.0
# 18시    14428248.0
# 12시    14625998.0
# 14시    14930304.0
# 8시     14966636.0
# 11시    15064617.0
# 17시    15081849.0
# 13시    15139608.0
# 10시    15159740.0
# 9시     15194714.0
# 15시    15330781.0
# 16시    15357299.0
# dtype: float64

# %%
data_201801_총유출.sort_values()

#유출교통량은 유입과 마찬가지로 새벽 3시가 가장 적고 그 다음 4시 2시 1시 임을 알 수 있다. 
#가장 많은 시간대는 16시,17시이다
# Out:
# 3시      3485340.0
# 4시      3713932.0
# 2시      4130293.0
# 1시      5321847.0
# 5시      5679713.0
# 0시      6863964.0
# 23시     9093482.0
# 6시      9384629.0
# 22시    11457210.0
# 7시     12355922.0
# 21시    12544848.0
# 20시    12903329.0
# 8시     13839180.0
# 19시    14049398.0
# 9시     14123570.0
# 10시    14352351.0
# 12시    14387913.0
# 11시    14577618.0
# 14시    14834402.0
# 13시    14862687.0
# 18시    15066556.0
# 15시    15443304.0
# 17시    15595920.0
# 16시    15655708.0
# dtype: float64

# %% [markdown]
# # 교통량이 가장 많은 지점은? 유입/유출

# %%
#분기별 (유입) 

data_201603_유입
data_201604_유입
data_201701_유입
data_201702_유입
data_201703_유입
data_201704_유입
data_201801_유입

# %%
data_201801_유입.head()
# Out:
#          일자 요일        지점명  지점번호  구분            방향     0시     1시     2시     3시  \
# 0  20180101  월  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  657.0  617.0  405.0  279.0
# 1  20180102  화  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  382.0  256.0  166.0  171.0
# 2  20180103  수  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  641.0  492.0  310.0  238.0
# 3  20180104  목  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  661.0  483.0  357.0  279.0
# 4  20180105  금  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  764.0  524.0  361.0  282.0
#
#     ...       14시     15시     16시     17시     18시     19시     20시     21시  \
# 0   ...    1401.0  1592.0  1515.0  1447.0  1192.0  1037.0   918.0   881.0
# 1   ...    1690.0  1835.0  1875.0  2021.0  2015.0  1612.0  1236.0  1308.0
# 2   ...    1841.0  2007.0  1940.0  2096.0  2209.0  1653.0  1387.0  1295.0
# 3   ...    1890.0  2030.0  2058.0  2123.0  2113.0  1619.0  1327.0  1379.0
# 4   ...    1860.0  2134.0  2163.0  2282.0  2307.0  1723.0  1577.0  1460.0
#
#       22시     23시
# 0   819.0   533.0
# ...

# %%
#지점별 시간대 교통량 (유입)

시간대별교통량_201603_유입 = data_201603_유입.groupby(['지점명'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum().sort_values(by='지점명')
시간대별교통량_201603_유입.head()
# Out:
#                      0시        1시        2시        3시        4시        5시  \
# 지점명
# 가양대교           139654.0  104231.0   82402.0   74224.0   88412.0  163590.0
# 강남대로(강남역-신분당)  114390.0   99169.0   79570.0   65740.0   68219.0   73224.0
# 강남대로(신사역)      234683.0  207762.0  177677.0  149573.0  139063.0  128115.0
# 강동대교            15147.0    9477.0    6537.0    5520.0    6711.0   16377.0
# 강변북로           363480.0  254113.0  180979.0  150569.0  191038.0  407291.0
#
#                      6시        7시        8시        9시    ...          14시  \
# 지점명                                                      ...
# 가양대교           245937.0  270938.0  324626.0  322988.0    ...     323802.0
# 강남대로(강남역-신분당)   94255.0  138670.0  147631.0  152861.0    ...     147008.0
# 강남대로(신사역)      140834.0  179705.0  199861.0  216854.0    ...     256322.0
# 강동대교            33990.0   44136.0   49296.0   52578.0    ...      66993.0
# 강변북로           613854.0  612383.0  630415.0  633271.0    ...     616554.0
#
# ...

# %%
시간대별교통량_201603_유입.head(50).plot(kind='barh', stacked = True, figsize = (10,10))

# %%
탑15교통량_201603_유입=시간대별교통량_201603_유입.sum(axis=1).sort_values(ascending=False).head(15)

# %%
탑15교통량_201603_유입.head()
# Out:
# 지점명
# 올림픽대로           12883928.0
# 강변북로            12121908.0
# 강변북로(난지한강공원)    10579520.0
# 한남대교             9990979.0
# 경부고속도로           9303821.0
# dtype: float64

# %%
시간대별교통량_201603_유입.sum(axis=1).sort_values(ascending=False).head(10).plot(kind='barh', figsize = (10,10))

# %%
시간대별교통량_201604_유입 = data_201604_유입.groupby(['지점명','지점번호'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum()
시간대별교통량_201701_유입 = data_201701_유입.groupby(['지점명','지점번호'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum()
시간대별교통량_201702_유입 = data_201702_유입.groupby(['지점명','지점번호'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum()
시간대별교통량_201703_유입 = data_201703_유입.groupby(['지점명','지점번호'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum()
시간대별교통량_201704_유입 = data_201704_유입.groupby(['지점명','지점번호'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum()
시간대별교통량_201801_유입 = data_201801_유입.groupby(['지점명','지점번호'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum()

# %%
탑15교통량_201604_유입=시간대별교통량_201604_유입.sum(axis=1).sort_values(ascending=False).head(15)
탑15교통량_201701_유입=시간대별교통량_201701_유입.sum(axis=1).sort_values(ascending=False).head(15)
탑15교통량_201702_유입=시간대별교통량_201702_유입.sum(axis=1).sort_values(ascending=False).head(15)
탑15교통량_201703_유입=시간대별교통량_201703_유입.sum(axis=1).sort_values(ascending=False).head(15)
탑15교통량_201704_유입=시간대별교통량_201704_유입.sum(axis=1).sort_values(ascending=False).head(15)
탑15교통량_201801_유입=시간대별교통량_201801_유입.sum(axis=1).sort_values(ascending=False).head(15)

# %%
탑15교통량_201604_유입.head()
# Out:
# 지점명           지점번호
# 올림픽대로         F-01    13011803.0
# 강변북로          F-02    12222271.0
# 강변북로(난지한강공원)  B-36    10397539.0
# 경부고속도로        F-06     9362379.0
# 경부고속도로(양재IC)  B-11     9362379.0
# dtype: float64

# %%
탑15교통량_201701_유입.head()
# Out:
# 지점명           지점번호
# 올림픽대로         F-01    11338931.0
# 강변북로          F-02     9710035.0
# 경부고속도로(양재IC)  B-11     9188560.0
# 경부고속도로        F-06     8034505.0
# 강변북로(난지한강공원)  B-36     7617359.0
# dtype: float64

# %%
탑15교통량_201702_유입.head()
# Out:
# 지점명           지점번호
# 올림픽대로         F-01    11534415.0
# 강변북로          F-02     9388111.0
# 경부고속도로(양재IC)  B-11     9231083.0
# 한남대교          C-13     8317782.0
# 경부고속도로        F-06     8294667.0
# dtype: float64

# %%
탑15교통량_201703_유입.head()
# Out:
# 지점명           지점번호
# 올림픽대로         F-01    12730758.0
# 강변북로          F-02    10894326.0
# 강변북로(난지한강공원)  B-36     9926386.0
# 한남대교          C-13     9598289.0
# 경부고속도로        F-06     9171684.0
# dtype: float64

# %%
탑15교통량_201704_유입.head()
# Out:
# 지점명           지점번호
# 올림픽대로         F-01    12604891.0
# 강변북로          F-02    10759608.0
# 강변북로(난지한강공원)  B-36     9707885.0
# 한남대교          C-13     9393478.0
# 경부고속도로        F-06     8942954.0
# dtype: float64

# %%
탑15교통량_201801_유입.head()
# Out:
# 지점명           지점번호
# 올림픽대로         F-01    7956870.0
# 강변북로          F-02    6788562.0
# 경부고속도로        F-06    5606332.0
# 강변북로(난지한강공원)  B-36    5553930.0
# 경부고속도로(양재IC)  B-11    5438771.0
# dtype: float64

# %%
시간대별교통량_201604_유입.sum(axis=1).sort_values(ascending=False).head(10).plot(kind='barh', figsize = (10,10))

# %%
시간대별교통량_201701_유입.sum(axis=1).sort_values(ascending=False).head(10).plot(kind='barh', figsize = (10,10))

# %%
시간대별교통량_201702_유입.sum(axis=1).sort_values(ascending=False).head(10).plot(kind='barh', figsize = (10,10))

# %%
시간대별교통량_201703_유입.sum(axis=1).sort_values(ascending=False).head(10).plot(kind='barh', figsize = (10,10))

# %%
시간대별교통량_201704_유입.sum(axis=1).sort_values(ascending=False).head(10).plot(kind='barh', figsize = (10,10))

# %%
시간대별교통량_201801_유입.sum(axis=1).sort_values(ascending=False).head(10).plot(kind='barh', figsize = (10,10))

# %%
#분기별 (유출)

data_201603_유출
data_201604_유출
data_201701_유출
data_201702_유출
data_201703_유출
data_201704_유출
data_201801_유출

# %%
#지점별 시간대 교통량 (유출)

시간대별교통량_201603_유출 = data_201603_유출.groupby(['지점명','지점번호'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum()
시간대별교통량_201603_유출.head()
# Out:
#                           0시        1시        2시        3시        4시  \
# 지점명           지점번호
# 가양대교          C-03  123366.0   91290.0   72372.0   64212.0   76530.0
# 강남대로(강남역-신분당) D-35  112824.0   96456.0   77107.0   63841.0   65734.0
# 강남대로(신사역)     D-43  166757.0  145589.0  124712.0  105117.0   93086.0
# 강동대교          C-22   15708.0    9740.0    7168.0    8316.0   18184.0
# 강변북로          F-02  337323.0  235401.0  170747.0  138426.0  145065.0
#
#                           5시        6시        7시        8시        9시  \
# 지점명           지점번호
# 가양대교          C-03  141157.0  236252.0  238337.0  268816.0  293284.0
# 강남대로(강남역-신분당) D-35   72936.0   95216.0  142296.0  150486.0  155736.0
# 강남대로(신사역)     D-43  109343.0  163210.0  225378.0  226738.0  224231.0
# 강동대교          C-22   53536.0   70080.0   76052.0   75164.0   83772.0
# 강변북로          F-02  240938.0  484617.0  562716.0  583293.0  597875.0
#
#                       ...          14시       15시       16시       17시  \
# ...

# %%
시간대별교통량_201604_유출 = data_201604_유출.groupby(['지점명','지점번호'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum()
시간대별교통량_201701_유출 = data_201701_유출.groupby(['지점명','지점번호'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum()
시간대별교통량_201702_유출 = data_201702_유출.groupby(['지점명','지점번호'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum()
시간대별교통량_201703_유출 = data_201703_유출.groupby(['지점명','지점번호'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum()
시간대별교통량_201704_유출 = data_201704_유출.groupby(['지점명','지점번호'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum()
시간대별교통량_201801_유출 = data_201801_유출.groupby(['지점명','지점번호'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum()

# %%
시간대별교통량_201604_유출.head(50).plot(kind='barh', stacked = True, figsize = (10,10))

# %%
탑15교통량_201603_유출=시간대별교통량_201603_유출.sum(axis=1).sort_values(ascending=False).head(15)
탑15교통량_201604_유출=시간대별교통량_201604_유출.sum(axis=1).sort_values(ascending=False).head(15)
탑15교통량_201701_유출=시간대별교통량_201701_유출.sum(axis=1).sort_values(ascending=False).head(15)
탑15교통량_201702_유출=시간대별교통량_201702_유출.sum(axis=1).sort_values(ascending=False).head(15)
탑15교통량_201703_유출=시간대별교통량_201703_유출.sum(axis=1).sort_values(ascending=False).head(15)
탑15교통량_201704_유출=시간대별교통량_201704_유출.sum(axis=1).sort_values(ascending=False).head(15)
탑15교통량_201801_유출=시간대별교통량_201801_유출.sum(axis=1).sort_values(ascending=False).head(15)

# %%
탑15교통량_201603_유출.head()
# Out:
# 지점명           지점번호
# 강변북로(난지한강공원)  B-36    13141440.0
# 경부고속도로(양재IC)  B-11    11332999.0
# 강변북로          F-02    11035406.0
# 올림픽대로         F-01    10757377.0
# 한남대교          C-13     9802714.0
# dtype: float64

# %%
탑15교통량_201604_유출.head()
# Out:
# 지점명           지점번호
# 강변북로(난지한강공원)  B-36    12979210.0
# 경부고속도로(양재IC)  B-11    11319043.0
# 강변북로          F-02    11231704.0
# 올림픽대로         F-01    10534537.0
# 경부고속도로        F-06     9732622.0
# dtype: float64

# %%
탑15교통량_201701_유출.head()
# Out:
# 지점명           지점번호
# 강변북로(난지한강공원)  B-36    10870218.0
# 강변북로          F-02    10572588.0
# 경부고속도로(양재IC)  B-11     9667684.0
# 경부고속도로        F-06     8296756.0
# 성산대교          C-04     7249676.0
# dtype: float64

# %%
탑15교통량_201702_유출.head()
# Out:
# 지점명           지점번호
# 강변북로(난지한강공원)  B-36    11034185.0
# 강변북로          F-02    10324568.0
# 경부고속도로(양재IC)  B-11     9978155.0
# 경부고속도로        F-06     8448066.0
# 올림픽대로         F-01     7698353.0
# dtype: float64

# %%
탑15교통량_201703_유출.head()
# Out:
# 지점명           지점번호
# 강변북로(난지한강공원)  B-36    12584755.0
# 강변북로          F-02    11422699.0
# 경부고속도로        F-06     9448164.0
# 경부고속도로(양재IC)  B-11     9346545.0
# 한남대교          C-13     9329766.0
# dtype: float64

# %%
탑15교통량_201704_유출.head()
# Out:
# 지점명           지점번호
# 강변북로(난지한강공원)  B-36    12354427.0
# 강변북로          F-02    11814084.0
# 경부고속도로        F-06     9521587.0
# 경부고속도로(양재IC)  B-11     8444140.0
# 한남대교          C-13     8251320.0
# dtype: float64

# %%
탑15교통량_201801_유출.head()
# Out:
# 지점명           지점번호
# 강변북로(난지한강공원)  B-36    7554320.0
# 강변북로          F-02    7366665.0
# 올림픽대로         F-01    6106481.0
# 경부고속도로        F-06    5832764.0
# 경부고속도로(양재IC)  B-11    5155536.0
# dtype: float64

# %% [markdown]
# # 교통량이 가장 많은 요일은? 유입/유출

# %%
data_201603_유입.head()
# Out:
#          일자 요일        지점명  지점번호  구분            방향     0시     1시     2시     3시  \
# 0  20160701  금  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  848.0  662.0  440.0  346.0
# 1  20160702  토  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  758.0  539.0  444.0  335.0
# 2  20160703  일  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  713.0  504.0  413.0  281.0
# 3  20160704  월  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  477.0  345.0  247.0  189.0
# 4  20160705  화  성산로(금화터널)  A-01  유입  봉원고가차도->독립문역  613.0  488.0  312.0  252.0
#
#     ...       14시     15시     16시     17시     18시     19시     20시     21시  \
# 0   ...    1993.0  1777.0  2086.0  2211.0  2270.0  1950.0  1740.0  1379.0
# 1   ...    2189.0  1983.0  2110.0  2138.0  1849.0  1590.0  1226.0  1342.0
# 2   ...    1694.0  1707.0  1539.0  1650.0  1375.0  1237.0  1144.0  1149.0
# 3   ...    1957.0  2020.0  2078.0  2133.0  2086.0  1749.0  1358.0  1334.0
# 4   ...    2056.0  2053.0  2201.0  2309.0  2243.0  1717.0  1396.0  1434.0
#
#       22시     23시
# 0  1218.0   985.0
# ...

# %%
data_201603_요일_유입=data_201603_유입.drop(['구분','방향','지점번호','일자'], axis=1)
data_201603_요일_유입.head()
# Out:
#   요일        지점명     0시     1시     2시     3시     4시     5시      6시      7시  \
# 0  금  성산로(금화터널)  848.0  662.0  440.0  346.0  349.0  738.0  1830.0  2861.0
# 1  토  성산로(금화터널)  758.0  539.0  444.0  335.0  351.0  568.0   903.0  1161.0
# 2  일  성산로(금화터널)  713.0  504.0  413.0  281.0  261.0  399.0   607.0   802.0
# 3  월  성산로(금화터널)  477.0  345.0  247.0  189.0  307.0  893.0  2205.0  3031.0
# 4  화  성산로(금화터널)  613.0  488.0  312.0  252.0  337.0  640.0  1762.0  2630.0
#
#     ...       14시     15시     16시     17시     18시     19시     20시     21시  \
# 0   ...    1993.0  1777.0  2086.0  2211.0  2270.0  1950.0  1740.0  1379.0
# 1   ...    2189.0  1983.0  2110.0  2138.0  1849.0  1590.0  1226.0  1342.0
# 2   ...    1694.0  1707.0  1539.0  1650.0  1375.0  1237.0  1144.0  1149.0
# 3   ...    1957.0  2020.0  2078.0  2133.0  2086.0  1749.0  1358.0  1334.0
# 4   ...    2056.0  2053.0  2201.0  2309.0  2243.0  1717.0  1396.0  1434.0
#
#       22시     23시
# 0  1218.0   985.0
# 1  1264.0  1058.0
# ...

# %%
요일별교통량_201603_유입 = data_201603_요일_유입.groupby(['지점명','요일'])['0시','1시','2시','3시','4시','5시','6시','7시','8시','9시','10시','11시','12시','13시','14시','15시','16시','17시','18시','19시','20시','21시','22시','23시'].sum()
요일별교통량_201603_유입
# Out:
#                        0시       1시       2시       3시       4시       5시  \
# 지점명           요일
# 가양대교          금   23409.0  17363.0  13464.0  11540.0  13726.0  26383.0
#               목   20709.0  15182.0  11704.0  10534.0  12562.0  24260.0
#               수   20486.0  14777.0  11556.0  10376.0  12466.0  23903.0
#               월   13977.0  10397.0   8348.0   8407.0  11482.0  25738.0
#               일   19584.0  14826.0  12000.0  10497.0  11141.0  15935.0
#               토   22354.0  17439.0  14205.0  12696.0  14919.0  23023.0
#               화   19135.0  14247.0  11125.0  10174.0  12116.0  24348.0
# 강남대로(강남역-신분당) 금   18416.0  16831.0  13139.0  10289.0  10384.0  11107.0
#               목   16443.0  14985.0  11387.0   9052.0   9116.0   9657.0
#               수   17029.0  14383.0  10984.0   8777.0   9321.0  10372.0
#               월   13351.0  10223.0   8337.0   7650.0   8761.0   9794.0
#               일   16743.0  14335.0  11660.0  10251.0  10792.0  10799.0
# ...

# %%
요일별교통량_201603_유입.head(50).plot(kind='barh', stacked = True, figsize = (10,10))

# %% [markdown]
# # 지점 별 유입/유출 교통량

# %%
#교통량이 많은 지점일 수록 따릉이 이용이 증가하는가? (상관관계)
#교통량이 많은 지점에 대여소를 더 많이 설치하는 것이 바람직한가?

# %% [markdown]
# # 지도 시각화

# %%
import folium

# %%
map1 = folium.Map(location = [37.566535, 126.97796919999996], zoom_start = 15)
map1

# %%
from pyproj import Proj, transform

# %%
def convert(x,y):
    inProj = Proj(init = 'epsg:5181')
    outProj = Proj(init = 'epsg:4326')
    x2,y2 = transform(inProj, outProj, x, y)
    return [y2, x2]

# %%
측정위치50['위경도'] = 측정위치50.apply(lambda 지점: convert(지점['X좌표'], 지점['Y좌표']), axis = 1)
측정위치50.head(3)

# %%
for row in 측정위치50.iterrows():
    folium.Marker(row[1]['위경도'], popup = row[1]['조사지점명']).add_to(map1)
